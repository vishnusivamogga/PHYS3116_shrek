# %%
# !pip install numpy pandas
# !pip install matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\amity\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/113.8 kB ? eta -:--:--
#      ---------- ---------------------------- 30.7/113.8 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 113.8/113.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/8.1 MB 6.9 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/8.1 MB 7.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/8.1 MB 6.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/8.1 MB 6.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.1/8.1 MB 6.5 MB/s eta 0:00:02
# ...

# %% [markdown]
# **Bold**
